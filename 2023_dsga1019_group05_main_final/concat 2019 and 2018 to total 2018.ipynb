# %%
import pandas as pd
import numpy as np

# %%
df_2018 = pd.read_csv('Parking_Violations_Issued_-_Fiscal_Year_2018.csv')
df_2018.head()
# Out:
# /Users/gary/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (29,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1434219940  CWY5549                 NY        PAS  01/01/2018
# 1      1434219963  HCR6106                 NY        PAS  01/01/2018
# 2      1434219951  GZX6116                 NY        PAS  01/01/2018
# 3      1429186926  HSH4411                 NY        PAS  01/01/2018
# 4      1434582802  53216ME                 NY        COM  01/01/2018
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              71               SDN        HYUND              P         19210
# 1              71               VAN        HONDA              P         18970
# ...

# %%
df_2019 = pd.read_csv('Parking_Violations_Issued_-_Fiscal_Year_2019.csv')
df_2019.head()
# Out:
# /Users/gary/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (17,18,20,22,23,29,30,31,32,36,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1442479747  HCP7926                 NY        PAS  07/16/2018
# 1      1442479759  HSZ2472                 NY        PAS  07/13/2018
# 2      1442479772  HYJ1988                 NY        PAS  07/13/2018
# 3      1442480397  HNV6246                 NY        PAS  07/13/2018
# 4      1442480403  HWG4025                 NY        PAS  07/13/2018
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              21               SDN        ME/BE              S             0
# 1              21              SUBN        ME/BE              S         49230
# ...

# %%
df_2018['Issue Date']= pd.to_datetime(df_2018['Issue Date']) 
df_2019['Issue Date']= pd.to_datetime(df_2019['Issue Date'])

# %%
df_2018['Year'] = df_2018['Issue Date'].dt.year 
df_2018['Month'] = df_2018['Issue Date'].dt.month
df_2018['Day'] = df_2018['Issue Date'].dt.day
df_2019['Year'] = df_2019['Issue Date'].dt.year 
df_2019['Month'] = df_2019['Issue Date'].dt.month
df_2019['Day'] = df_2019['Issue Date'].dt.day

# %%
df_2018_sp = df_2018[df_2018['Year'] == 2018]
df_2018_sp
# Out:
#          Summons Number  Plate ID Registration State Plate Type Issue Date  \
# 0            1434219940   CWY5549                 NY        PAS 2018-01-01
# 1            1434219963   HCR6106                 NY        PAS 2018-01-01
# 2            1434219951   GZX6116                 NY        PAS 2018-01-01
# 3            1429186926   HSH4411                 NY        PAS 2018-01-01
# 4            1434582802   53216ME                 NY        COM 2018-01-01
# ...                 ...       ...                ...        ...        ...
# 5716322      1435384519   DZW6526                 NY        PAS 2018-12-31
# 5716323      1435367728   30501MG                 NY        COM 2018-12-31
# 5716324      1414253448  T683534C                 NY        OMT 2018-12-31
# 5716325      1414253436     1G94A                 NY        OMT 2018-12-31
# 5716326      1426059607   81660Z1                 CA        PAS 2018-12-31
#
# ...

# %%
df_2018_fa = df_2019[df_2019['Year'] == 2018]
df_2018_fa
# Out:
#           Summons Number Plate ID Registration State Plate Type Issue Date  \
# 0             1442479747  HCP7926                 NY        PAS 2018-07-16
# 1             1442479759  HSZ2472                 NY        PAS 2018-07-13
# 2             1442479772  HYJ1988                 NY        PAS 2018-07-13
# 3             1442480397  HNV6246                 NY        PAS 2018-07-13
# 4             1442480403  HWG4025                 NY        PAS 2018-07-13
# ...                  ...      ...                ...        ...        ...
# 11060085      1459305681  2431508                 99        COM 2018-08-15
# 11060612      1459309170   XZ696T                 NJ        PAS 2018-05-17
# 11062498      1459345733  96072MG                 NY        COM 2018-05-24
# 11063548      1459560917  23276TC                 NY        TRC 2018-06-12
# 11065610      1459409322  68224MM                 NY        COM 2018-05-24
#
# ...

# %%
df_2018_total = pd.concat([df_2018_sp, df_2018_fa])

# %%
df_2018_total.to_csv('df_2018_total.csv', index = False)

# %%
pd.read_csv('df_2019_total.csv')
# Out:
# /Users/gary/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (17,18,20,22,23,29,30,31,32,36,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0             1442489595   HUJ8826                 NY        PAS  2019-07-10
# 1             1442525642   HXS1441                 NY        PAS  2019-07-16
# 2             1442847890   HHT6079                 NY        PAS  2019-07-18
# 3             1442924561   HNG2700                 NY        PAS  2019-07-20
# 4             1133401594   HPC9135                 NY        PAS  2019-07-02
# ...                  ...       ...                ...        ...         ...
# 12773444      1448875237   JHL8867                 NY        PAS  2019-12-31
# ...
